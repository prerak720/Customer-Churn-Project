# %% [markdown]
# #### Problem Statement:
# You are the data scientist at a telecom company named “Neo” whose customers
# are churning out to its competitors. You have to analyze the data of your
# company and find insights and stop your customers from churning out to other
# telecom companies.

# %% [markdown]
# #### -  Prerak Pandaya

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Prerak\Desktop\Customer Churn Project\customer_churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %% [markdown]
# 1. Data Manipulation:
#
# ● Extract the 5th column and store it in ‘customer_5’
#
# ● Extract the 15th column and store it in ‘customer_15’
#
# ● Extract all the male senior citizens whose payment method is electronic
# check and store the result in ‘senior_male_electronic’
#
# ● Extract all those customers whose tenure is greater than 70 months or
# their monthly charges is more than $100 and store the result in
# ‘customer_total_tenure’
#
# ● Extract all the customers whose contract is of two years, payment method
# is mailed check and the value of churn is ‘Yes’ and store the result in
# ‘two_mail_yes’
#
# ● Extract 333 random records from the customer_churndataframe and store
# the result in ‘customer_333’
#
# ● Get the count of different levels from the ‘Churn’ column

# %%
cuatomer_5 = df['tenure']

# %%
customer_15 = df['Contract']

# %%
Male = df[df['gender'] == 'Male']
round(Male['tenure'].mean())
senior_male_electronic = Male[Male['tenure'] >= 32]

# %%
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 3     7795-CFOCW   Male              0      No         No      45
# 9     6388-TABGU   Male              0      No        Yes      62
# 12    8091-TTVAX   Male              0     Yes         No      58
# 13    0280-XJGEX   Male              0      No         No      49
# ...          ...    ...            ...     ...        ...     ...
# 7022  7203-OYKCT   Male              0      No         No      72
# 7024  7398-LXGYX   Male              0     Yes         No      44
# 7031  3605-JISKB   Male              1     Yes         No      55
# 7033  9767-FFLEM   Male              0      No         No      38
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 9             Yes                No             DSL            Yes  ...
# 12            Yes               Yes     Fiber optic             No  ...
# 13            Yes               Yes     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7022          Yes               Yes     Fiber optic             No  ...
# 7024          Yes               Yes     Fiber optic            Yes  ...
# 7031          Yes               Yes             DSL            Yes  ...
# 7033          Yes                No     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 1                 Yes          No          No              No        One year
# 3                 Yes         Yes          No              No        One year
# 9                  No          No          No              No        One year
# 12                Yes          No         Yes             Yes        One year
# 13                Yes          No         Yes             Yes  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7022              Yes          No         Yes             Yes        One year
# 7024              Yes          No          No              No  Month-to-month
# 7031               No          No          No              No        One year
# 7033               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 1                  No               Mailed check          56.95        1889.5
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 9                  No  Bank transfer (automatic)          56.15       3487.95
# 12                 No    Credit card (automatic)         100.35        5681.1
# 13                Yes  Bank transfer (automatic)         103.70        5036.3
# ...               ...                        ...            ...           ...
# 7022              Yes           Electronic check         104.95        7544.3
# 7024              Yes    Credit card (automatic)          84.80       3626.35
# 7031               No    Credit card (automatic)          60.00        3316.1
# 7033              Yes    Credit card (automatic)          69.50       2625.25
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 1       No
# 3       No
# 9       No
# 12      No
# 13     Yes
# ...    ...
# 7022    No
# 7024    No
# 7031    No
# 7033    No
# 7042    No
#
# [1682 rows x 21 columns]

# %%
customer_total_tenure = df[(df['tenure'] == 70) & (df['MonthlyCharges'] > 100)]

# %%
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 152   1679-JRFBR  Female              0     Yes        Yes      70
# 737   2521-NPUZR    Male              0     Yes         No      70
# 811   4853-RULSV    Male              0      No         No      70
# 1306  0201-OAMXR  Female              0      No         No      70
# 1422  3870-SPZSI  Female              0     Yes        Yes      70
# 2079  5804-HYIEZ    Male              0     Yes        Yes      70
# 2164  5453-YBTWV    Male              0     Yes        Yes      70
# 2228  3597-YASZG  Female              1     Yes         No      70
# 2264  7176-WRTNX    Male              0      No         No      70
# 2540  7055-JCGNI  Female              0      No         No      70
# 2636  0907-HQNTS  Female              1     Yes         No      70
# 2879  4550-VBOFE    Male              1     Yes         No      70
# 3117  9844-FELAJ  Female              1     Yes        Yes      70
# 3409  4806-DXQCE  Female              1     Yes         No      70
# 3450  0100-DUVFC    Male              1     Yes         No      70
# 3508  2368-GAKKQ  Female              0      No         No      70
# 3517  0748-RDGGM    Male              0     Yes         No      70
# 3606  2623-DRYAM  Female              0     Yes         No      70
# 5200  6050-IJRHS  Female              0     Yes        Yes      70
# 5254  4393-GEADV    Male              0     Yes        Yes      70
# 5420  7929-SKFGK    Male              0     Yes         No      70
# 5654  1576-PFZIW    Male              1     Yes         No      70
# 5697  1984-FCOWB  Female              0     Yes         No      70
# 5710  6297-NOOPG  Female              0     Yes         No      70
# 5727  8707-HOEDG  Female              0     Yes        Yes      70
# 5819  3396-DKDEL  Female              0     Yes        Yes      70
# 6038  1555-DJEQW  Female              0     Yes        Yes      70
# 6278  7208-PSIHR  Female              0     Yes         No      70
# 6390  6994-FGRHH    Male              0     Yes        Yes      70
# 6537  1444-VVSGW    Male              0     Yes         No      70
# 6566  3795-CAWEX    Male              0     Yes        Yes      70
# 6799  8071-SBTRN  Female              0      No         No      70
# 6805  4323-OHFOW  Female              1     Yes         No      70
# 6910  0530-IJVDB    Male              0      No        Yes      70
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 152           Yes           Yes     Fiber optic            Yes  ...
# 737           Yes            No     Fiber optic            Yes  ...
# 811           Yes           Yes     Fiber optic            Yes  ...
# 1306          Yes           Yes     Fiber optic            Yes  ...
# 1422          Yes           Yes     Fiber optic            Yes  ...
# 2079          Yes           Yes     Fiber optic            Yes  ...
# 2164          Yes            No     Fiber optic            Yes  ...
# 2228          Yes           Yes     Fiber optic             No  ...
# 2264          Yes           Yes     Fiber optic            Yes  ...
# 2540          Yes           Yes     Fiber optic            Yes  ...
# 2636          Yes           Yes     Fiber optic            Yes  ...
# 2879          Yes           Yes     Fiber optic             No  ...
# 3117          Yes           Yes     Fiber optic             No  ...
# 3409          Yes           Yes     Fiber optic            Yes  ...
# 3450          Yes           Yes     Fiber optic             No  ...
# 3508          Yes           Yes     Fiber optic            Yes  ...
# 3517          Yes            No     Fiber optic            Yes  ...
# 3606          Yes           Yes     Fiber optic             No  ...
# 5200          Yes           Yes     Fiber optic             No  ...
# 5254          Yes           Yes     Fiber optic            Yes  ...
# 5420          Yes           Yes     Fiber optic            Yes  ...
# 5654          Yes            No     Fiber optic            Yes  ...
# 5697          Yes           Yes     Fiber optic             No  ...
# 5710          Yes           Yes     Fiber optic             No  ...
# 5727          Yes           Yes     Fiber optic             No  ...
# 5819          Yes           Yes     Fiber optic            Yes  ...
# 6038          Yes           Yes     Fiber optic            Yes  ...
# 6278          Yes           Yes     Fiber optic             No  ...
# 6390          Yes            No     Fiber optic             No  ...
# 6537          Yes           Yes     Fiber optic            Yes  ...
# 6566          Yes           Yes     Fiber optic            Yes  ...
# 6799          Yes           Yes     Fiber optic            Yes  ...
# 6805          Yes           Yes     Fiber optic             No  ...
# 6910          Yes           Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 152               Yes          No         Yes             Yes        One year
# 737               Yes         Yes          No             Yes        Two year
# 811                No         Yes         Yes             Yes        Two year
# 1306              Yes         Yes         Yes             Yes        One year
# 1422              Yes         Yes         Yes             Yes        Two year
# 2079               No          No         Yes             Yes  Month-to-month
# 2164              Yes         Yes         Yes              No        Two year
# 2228               No         Yes         Yes             Yes        Two year
# 2264              Yes         Yes         Yes             Yes        Two year
# 2540              Yes         Yes         Yes             Yes        Two year
# 2636              Yes         Yes         Yes             Yes        Two year
# 2879              Yes          No         Yes             Yes  Month-to-month
# 3117              Yes         Yes         Yes             Yes        One year
# 3409              Yes         Yes         Yes             Yes        Two year
# 3450              Yes          No         Yes             Yes        One year
# 3508              Yes         Yes         Yes             Yes        Two year
# 3517              Yes         Yes         Yes             Yes        One year
# 3606              Yes          No         Yes             Yes        One year
# 5200              Yes          No         Yes             Yes        One year
# 5254              Yes         Yes         Yes             Yes        Two year
# 5420              Yes         Yes         Yes             Yes        Two year
# 5654              Yes          No         Yes             Yes        Two year
# 5697              Yes         Yes         Yes             Yes        One year
# 5710              Yes         Yes         Yes             Yes        Two year
# 5727              Yes         Yes         Yes             Yes        Two year
# 5819              Yes         Yes         Yes             Yes        Two year
# 6038              Yes         Yes         Yes             Yes        Two year
# 6278              Yes         Yes         Yes             Yes        Two year
# 6390              Yes         Yes         Yes             Yes        One year
# 6537              Yes         Yes         Yes             Yes        One year
# 6566              Yes         Yes         Yes             Yes        Two year
# 6799              Yes          No         Yes             Yes        Two year
# 6805               No         Yes         Yes             Yes        One year
# 6910              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 152               Yes    Credit card (automatic)         108.15       7930.55
# 737                No    Credit card (automatic)         101.00        7085.5
# 811               Yes    Credit card (automatic)         104.00       7250.15
# 1306               No    Credit card (automatic)         115.55        8127.6
# 1422              Yes    Credit card (automatic)         113.05       7869.05
# 2079              Yes           Electronic check         106.05       7554.05
# 2164              Yes    Credit card (automatic)         101.10        6994.8
# 2228              Yes  Bank transfer (automatic)         104.45       7349.35
# 2264              Yes  Bank transfer (automatic)         114.95       7711.25
# 2540              Yes    Credit card (automatic)         111.95       7795.95
# 2636              Yes    Credit card (automatic)         113.00        7987.6
# 2879              Yes           Electronic check         102.95        7101.5
# 3117              Yes           Electronic check         107.90       7475.85
# 3409              Yes           Electronic check         113.65       7714.65
# 3450              Yes           Electronic check         104.80       7308.95
# 3508              Yes  Bank transfer (automatic)         113.65       7939.25
# 3517              Yes  Bank transfer (automatic)         109.50       7534.65
# 3606              Yes           Electronic check         101.75        7069.3
# 5200              Yes           Electronic check         106.50          7397
# 5254               No    Credit card (automatic)         114.75        7842.3
# 5420               No    Credit card (automatic)         114.30        8244.3
# 5654               No    Credit card (automatic)         105.35        7511.9
# 5697              Yes           Electronic check         109.50       7674.55
# 5710              Yes           Electronic check         110.50       7752.05
# 5727              Yes           Electronic check         110.20        7689.8
# 5819              Yes    Credit card (automatic)         115.15          8250
# 6038              Yes  Bank transfer (automatic)         114.20        7723.9
# 6278              Yes  Bank transfer (automatic)         104.30        7188.5
# 6390              Yes           Electronic check         106.15        7475.1
# 6537               No    Credit card (automatic)         115.65       7968.85
# 6566              Yes    Credit card (automatic)         116.55        8152.3
# 6799              Yes               Mailed check         111.15       7737.55
# 6805              Yes  Bank transfer (automatic)         105.55       7195.35
# 6910              Yes           Electronic check         114.60        7882.5
#
#      Churn
# 152     No
# 737     No
# 811    Yes
# 1306   Yes
# 1422    No
# 2079    No
# 2164    No
# 2228    No
# 2264    No
# 2540    No
# 2636    No
# 2879   Yes
# 3117    No
# 3409    No
# 3450    No
# 3508    No
# 3517   Yes
# 3606    No
# 5200    No
# 5254    No
# 5420    No
# 5654    No
# 5697   Yes
# 5710    No
# 5727    No
# 5819    No
# 6038   Yes
# 6278    No
# 6390    No
# 6537   Yes
# 6566    No
# 6799    No
# 6805    No
# 6910    No
#
# [34 rows x 21 columns]

# %% [markdown]
# ##

# %% [markdown]
# Extract all the customers whose contract is of two years, payment method is mailed check and the value of churn is ‘Yes’ and store the result in ‘two_mail_yes’

# %%
two_mail_yes = df[(df['Contract'] == 'Two year') & (df['PaymentMethod'] == 'Mailed check') & (df['Churn'] == 'Yes')]

# %%
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# 268   No internet service  Two year               No  Mailed check
# 5947  No internet service  Two year              Yes  Mailed check
# 6680                   No  Two year              Yes  Mailed check
#
#      MonthlyCharges  TotalCharges Churn
# 268           19.35        1099.6   Yes
# 5947          24.50         740.3   Yes
# 6680          95.50       4627.85   Yes
#
# [3 rows x 21 columns]

# %% [markdown]
# Extract 333 random records from the customer_churndataframe and store
# the result in ‘customer_333’

# %%
customer_333 = df.sample(n = 333,random_state=22)

# %%
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6187  0224-NIJLP    Male              0     Yes        Yes       8
# 6448  3685-YLCMQ    Male              0      No         No      58
# 5492  2799-TSLAG  Female              0     Yes        Yes      65
# 2028  4452-ROHMO  Female              0      No         No      15
# 5376  9229-RQABD    Male              0      No         No      18
# ...          ...     ...            ...     ...        ...     ...
# 2107  7422-WNBTY    Male              0     Yes         No      33
# 6461  0419-YAAPX    Male              0     Yes         No      49
# 1041  1915-OAKWD  Female              0      No        Yes      16
# 6510  0572-ZJKLT  Female              0     Yes        Yes      46
# 5937  5383-MMTWC  Female              1     Yes         No       8
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 6187          Yes            No              No  No internet service  ...
# 6448          Yes           Yes     Fiber optic                   No  ...
# 5492          Yes           Yes              No  No internet service  ...
# 2028          Yes            No              No  No internet service  ...
# 5376          Yes           Yes              No  No internet service  ...
# ...           ...           ...             ...                  ...  ...
# 2107          Yes           Yes     Fiber optic                   No  ...
# 6461          Yes            No     Fiber optic                   No  ...
# 1041          Yes            No              No  No internet service  ...
# 6510          Yes           Yes     Fiber optic                  Yes  ...
# 5937          Yes           Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6187  No internet service  No internet service  No internet service
# 6448                  Yes                  Yes                  Yes
# 5492  No internet service  No internet service  No internet service
# 2028  No internet service  No internet service  No internet service
# 5376  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 2107                  Yes                   No                   No
# 6461                   No                   No                  Yes
# 1041  No internet service  No internet service  No internet service
# 6510                  Yes                  Yes                   No
# 5937                   No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6187  No internet service        Two year               No
# 6448                  Yes        One year              Yes
# 5492  No internet service        Two year              Yes
# 2028  No internet service        Two year               No
# 5376  No internet service        One year               No
# ...                   ...             ...              ...
# 2107                  Yes  Month-to-month              Yes
# 6461                   No  Month-to-month              Yes
# 1041  No internet service        One year              Yes
# 6510                  Yes        Two year               No
# 5937                  Yes  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 6187               Mailed check          20.15         165.5    No
# 6448           Electronic check         104.65        6219.6   Yes
# 5492  Bank transfer (automatic)          25.30       1748.55    No
# 2028               Mailed check          19.60         331.6    No
# 5376               Mailed check          23.75         424.5    No
# ...                         ...            ...           ...   ...
# 2107           Electronic check          93.35          3092    No
# 6461    Credit card (automatic)          85.30       4297.95    No
# 1041  Bank transfer (automatic)          19.30        360.35    No
# 6510               Mailed check          99.65        4630.2    No
# 5937           Electronic check          84.00         613.4   Yes
#
# [333 rows x 21 columns]

# %% [markdown]
# ##

# %% [markdown]
# Get the count of different levels from the ‘Churn’ column

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# ● Build a bar-plot for the ’InternetService’ column:
#
#     a. Set x-axis label to ‘Categories of Internet Service’
#
#     b. Set y-axis label to ‘Count of Categories’
#
#     c. Set the title of plot to be ‘Distribution of Internet Service’
#
#     d. Set the color of the bars to be ‘orange’
#
# ● Build a histogram for the ‘tenure’ column:
#
#     a. Set the number of bins to be 30
#
#     b. Set the color of the bins to be ‘green’
#
#     c. Assign the title ‘Distribution of tenure’
#
# ● Build a scatter-plot between ‘MonthlyCharges’ and ‘tenure’. Map
# ‘MonthlyCharges’ to the y-axis and ‘tenure’ to the ‘x-axis’:
#
#     a. Assign the points a color of ‘brown’
#
#     b. Set the x-axis label to ‘Tenure of customer’
#
#     c. Set the y-axis label to ‘Monthly Charges of customer’
#
#     d. Set the title to ‘Tenure vs Monthly Charges’
#
#     e. Build a box-plot between ‘tenure’ & ‘Contract’. Map ‘tenure’ on the
# y-axis &
#
# f. ‘Contract’ on the x-axis.

# %% [markdown]
# Build a bar-plot for the ’InternetService’ column:
#
#     a. Set x-axis label to ‘Categories of Internet Service’
#
#     b. Set y-axis label to ‘Count of Categories’
#
#     c. Set the title of plot to be ‘Distribution of Internet Service’
#
#     d. Set the color of the bars to be ‘orange’

# %%
sns.countplot(df,x = df['InternetService'],color='orange')
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of Categories')
plt.title('Distribution of Internet Service')
# Out:
# Text(0.5, 1.0, 'Distribution of Internet Service')

# %% [markdown]
#  Build a histogram for the ‘tenure’ column:
#
#     a. Set the number of bins to be 30
#
#     b. Set the color of the bins to be ‘green’
#
#     c. Assign the title ‘Distribution of tenure’

# %%
sns.histplot(df,x= 'tenure',bins=30,color='green')
plt.title('Distribution of tenure')
# Out:
# Text(0.5, 1.0, 'Distribution of tenure')

# %% [markdown]
# ● Build a scatter-plot between ‘MonthlyCharges’ and ‘tenure’. Map
# ‘MonthlyCharges’ to the y-axis and ‘tenure’ to the ‘x-axis’:
#
#     a. Assign the points a color of ‘brown’
#
#     b. Set the x-axis label to ‘Tenure of customer’
#
#     c. Set the y-axis label to ‘Monthly Charges of customer’
#
#     d. Set the title to ‘Tenure vs Monthly Charges’

# %%
sns.scatterplot(df,x = 'tenure',y = 'MonthlyCharges',color='brown')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly Charges of customer')
plt.title('Tenure vs Monthly Charges')
# Out:
# Text(0.5, 1.0, 'Tenure vs Monthly Charges')

# %% [markdown]
# e. Build a box-plot between ‘tenure’ & ‘Contract’. Map ‘tenure’ on the
# y-axis & ‘Contract’ on the x-axis.

# %%
sns.boxplot(df,x= 'tenure', y = 'Contract')
# Out:
# <Axes: xlabel='tenure', ylabel='Contract'>

# %% [markdown]
# ## LinerRegression

# %% [markdown]
# 3. Linear Regression:
#
# ● Build a simple linear model where dependent variable is ‘MonthlyCharges’
# and independent variable is ‘tenure’:
#
#     a. Divide the dataset into train and test sets in 70:30 ratio.
#
#         b. Build the model on train set and predict the values on test set
#
#         c. After predicting the values, find the root mean square error
#
#         d. Find out the error in prediction & store the result in ‘error’
#
#         e. Find the root mean square error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,mean_absolute_error,confusion_matrix

# %%
Model = LinearRegression()

# %%
x = df[['tenure']]
y = df[['MonthlyCharges']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=22)

# %%
model = li.fit(x_train,y_train)

# %%
prediction = model.predict(x_test)

# %%
mean_absolute_error(prediction,y_test)
# Out:
# 25.915315822267818

# %% [markdown]
# ## Logical Regression

# %% [markdown]
# 4. Logistic Regression:
#
# ● Build a simple logistic regression model where dependent variable is
# ‘Churn’ and independent variable is ‘MonthlyCharges’:
#
#     a. Divide the dataset in 65:35 ratio
#
#         b. Build the model on train set and predict the values on test set
#
#         c. Build the confusion matrix and get the accuracy score
#
#         d. Build a multiple logistic regression model where dependent variable
#                     is ‘Churn’ and independent variables are ‘tenure’ and
#                     ‘MonthlyCharges’
#
#     e. Divide the dataset in 80:20 ratio
#
#     f. Build the model on train set and predict the values on test set
#
#     g. Build the confusion matrix and get the

# %%
from sklearn.linear_model import LogisticRegression

# %%
x1 = df[['MonthlyCharges']]
y1 = df[['Churn']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=0.35,random_state=22)

# %%
lo =  LogisticRegression()

# %%
model2 = lo.fit(x_train,y_train)
# Out:
# C:\Users\Prerak\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pred = model2.predict(x_test)

# %%
accuracy_score(pred,y_test)
# Out:
# 0.727088402270884

# %%
confusion_matrix(pred,y_test)
# Out:
# array([[1793,  673],
#        [   0,    0]], dtype=int64)

# %%
# here we see 72 % accurancy we have

# %% [markdown]
# ### Decision Tree:
# ● Build a decision tree model where dependent variable is ‘Churn’ and
# independent variable is ‘tenure’:
# a. Divide the dataset in 80:20 ratio
# b. Build the model on train set and predict the values on test set
# c. Build the confusion matrix and calculate the accuracy

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
x2 = df[['tenure']]
y2 = df[['Churn']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x2,y2,test_size=0.20,random_state=34)

# %%
de = DecisionTreeClassifier()

# %%
model3 = de.fit(x_train,y_train)

# %%
pred2 = model3.predict(x_test)

# %%
accuracy_score(pred2,y_test)
# Out:
# 0.7508871540099361

# %%
confusion_matrix(pred2,y_test)
# Out:
# array([[943, 271],
#        [ 80, 115]], dtype=int64)

# %%
#Here we see the 75% accurancy we have

# %%
plt.figure(figsize=(20, 10))
plot_tree(de, feature_names=['tenure'], class_names=['Not Churn', 'Churn'], filled=True, rounded=True)
plt.show()

# %% [markdown]
# ### 6. Random Forest:
#
#     ● Build a Random Forest model where dependent variable is ‘Churn’ and
# independent variables are ‘tenure’ and ‘MonthlyCharges’:
#
#     a. Divide the dataset in 70:30 ratio
#
#         b. Build the model on train set and predict the values on test set
#
#         c. Build the confusion matrix and calculate the accuracy

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
re = RandomForestClassifier()

# %%
x4 =df[['MonthlyCharges']]
y4 = df[['Churn']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x4,y4,test_size=0.3,random_state=56)

# %%
model4 = re.fit(x_train,y_train)
# Out:
# C:\Users\Prerak\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
pred4 = model4.predict(x_test)

# %%
accuracy_score(pred4,y_test)
# Out:
# 0.6810222432560341

# %%
confusion_matrix(pred4,y_test)
# Out:
# array([[1295,  415],
#        [ 259,  144]], dtype=int64)

# %%
#here we Achive 68% Accurancy

# %% [markdown]
# ### - Prerak Pandya
